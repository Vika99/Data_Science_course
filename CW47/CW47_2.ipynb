# %%
import pandas as pd
import numpy as np
import pipes_2 as pp
#ниже строчка для если у нас несколько документов есть как pipes_2
#import bugFix.pipes2 as pp2

# %%
df = pd.read_csv('air_train.csv')

df = df.drop(['Unnamed: 0','id'], axis = 1)

# %%
df = pp.myPipe.transform(df)

# %%
df
# Out:
#         Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0            1              0   13               1      1              460
# 1            1              1   25               0      2              235
# 2            0              0   26               0      2             1142
# 3            0              0   25               0      2              562
# 4            1              0   61               0      2              214
# ...        ...            ...  ...             ...    ...              ...
# 103899       0              1   23               0      0              192
# 103900       1              0   49               0      2             2347
# 103901       1              1   30               0      2             1995
# 103902       0              1   22               0      0             1000
# 103903       1              0   27               0      2             1723
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# ...
