# %% [markdown]
# Даны матрицы А
#
# [[-0.05, -0.07,  0.34, -0.42,  0.  , -0.04, -0.33,  0.22,  0.28,
#          0.43, -0.2 ,  0.26,  0.1 , -0.8 , -0.62],
#        [ 0.62,  0.76,  0.68, -0.36,  0.  ,  0.39,  0.41,  0.81,  0.84,
#          0.48,  0.36,  0.11, -0.02, -0.79,  0.37],
#        [-0.36, -0.59,  0.68, -0.11,  0.  , -0.4 , -0.78, -0.59, -0.31,
#          0.11, -0.38,  0.18,  0.24,  0.23,  0.75],
#        [ 0.28,  0.17,  0.87, -0.53,  0.  , -0.39,  0.34, -0.17,  0.15,
#         -0.21,  0.34, -0.29, -0.41,  0.68,  0.62],
#        [-0.08,  0.07,  0.09, -0.3 ,  0.  , -0.73,  0.14,  0.38,  0.1 ,
#         -0.02, -0.55, -0.1 ,  0.31,  0.88,  0.18],
#        [-0.4 ,  0.41,  0.1 , -0.33,  0.  , -0.28,  0.1 ,  0.73, -0.25,
#          0.21, -0.17, -0.04,  0.08,  0.64, -0.25],
#        [ 0.29, -0.35, -0.34,  0.77,  0.  ,  0.03,  0.13,  0.82,  0.78,
#          0.64,  0.67, -0.04,  0.36,  0.79,  0.89],
#        [ 0.79,  0.56, -0.79,  0.57,  0.  , -0.44, -0.62,  0.69, -0.21,
#         -0.34, -0.22,  0.8 , -0.08, -0.54,  0.87],
#        [-0.76, -0.18, -0.37, -0.72,  0.  ,  0.46,  0.64,  0.7 , -0.16,
#          0.76,  0.31,  0.84,  0.  ,  0.39, -0.1 ],
#        [ 0.69,  0.66,  0.62, -0.07,  0.  ,  0.45,  0.47,  0.44,  0.69,
#         -0.03,  0.89,  0.19, -0.57, -0.73,  0.52],
#        [-0.37, -0.05, -0.29, -0.29,  0.  ,  0.83,  0.42, -0.75,  0.  ,
#          0.05, -0.35,  0.36, -0.13, -0.07,  0.04],
#        [-0.78, -0.71,  0.66,  0.22,  0.  , -0.67,  0.8 ,  0.2 ,  0.15,
#          0.39, -0.6 ,  0.62,  0.22, -0.75,  0.12],
#        [-0.65, -0.73,  0.45, -0.56,  0.  ,  0.07,  0.79,  0.75,  0.27,
#          0.83, -0.78,  0.85, -0.57,  0.35, -0.69],
#        [-0.28, -0.09, -0.32, -0.34,  0.  , -0.55, -0.63,  0.18,  0.46,
#         -0.49, -0.43,  0.54, -0.09,  0.84, -0.08],
#        [ 0.12,  0.4 ,  0.77,  0.4 ,  0.  ,  0.04,  0.66,  0.3 , -0.6 ,
#         -0.48, -0.48,  0.6 ,  0.11, -0.36,  0.14]]
#
# и В
#
#        [-70, -28,  19,  34, -70,  37,  84, -49,  -4, -74,  51,   6,  46,
#          75,  42],
#        [ 66,  15, -79,  66, -13,   0,  17, -15,   8,  25,  77,  64,  23,
#          34,  30],
#        [ -1,  34,  67, -13,  -7, -74, -63, -25,  48,  82,  38,  35,  30,
#          32, -16],
#        [ 74,  20, -53,   1, -28, -23,  73,  15, -27,  42, -62, -74,  51,
#          87,  46],
#        [ 55,  46,  33,  83,  80,  31,  21, -71,  26, -46,  39, -16,  77,
#          29, -35],
#        [ 78, -45, -16, -55, -79,  61, -77, -76,  55,  72,  29, -11, -58,
#          28,  52],
#        [  9, -78, -46,  87, -30, -16,  -5,  44, -30, -16, -26, -48,  -7,
#          34, -40],
#        [ 61, -47,  18, -16, -61, -55,  25,  37,  55,  66,  -5, -68, -29,
#         -22,  40],
#        [ -7, -44,  -6,  22,  36,  79, -15, -13,  24,   2,  57,  13, -47,
#          27, -22],
#        [ 58, -56, -65,  44, -53, -79,  21,  -7, -77,  31,  70,  55,  72,
#         -50,  -6],
#        [ 64, -29,  16, -61,  63, -52, -34, -19,  13, -74,  68, -66,  58,
#           7,  55],
#        [-79,  21, -64, -59, -16, -30,   4,   5, -54,   4,  20,  52, -11,
#         -20,  -2],
#        [-44, -72,  41, -33, -35,  34, -17,  47,   1,  25, -70,  26, -35,
#          57, -47],
#        [ 53,  38, -55, -24, -42,  33,  74,  32,  83,  79, -25,   2, -27,
#         -19,  46],
#        [ 11,  29,  10,  18,  39,  -1, -45, -56,  -6,  -7, -46,  10,  23,
#           5,   4]]
#
# 1 Найдете матрицу последовательного применения операторов А и В
#
# 2 Примените этот оператор к вектору b
#         [ 8.5,  7.8,  2.4, -4.4, -0.6,  7.7, -3.2, -5.3, -4. , -5.6, -3.7,
#        -2.2,  8.1, -1.1,  2.3]
#
# 3 Найдите матрицу обратного отображения

# %%
import numpy as np

# %%
A = np.array([[-0.05, -0.07, 0.34, -0.42, 0. , -0.04, -0.33, 0.22, 0.28, 0.43, -0.2 , 0.26, 0.1 , -0.8 , -0.62], [ 0.62, 0.76, 0.68, -0.36, 0. , 0.39, 0.41, 0.81, 0.84, 0.48, 0.36, 0.11, -0.02, -0.79, 0.37], [-0.36, -0.59, 0.68, -0.11, 0. , -0.4 , -0.78, -0.59, -0.31, 0.11, -0.38, 0.18, 0.24, 0.23, 0.75], [ 0.28, 0.17, 0.87, -0.53, 0. , -0.39, 0.34, -0.17, 0.15, -0.21, 0.34, -0.29, -0.41, 0.68, 0.62], [-0.08, 0.07, 0.09, -0.3 , 0. , -0.73, 0.14, 0.38, 0.1 , -0.02, -0.55, -0.1 , 0.31, 0.88, 0.18], [-0.4 , 0.41, 0.1 , -0.33, 0. , -0.28, 0.1 , 0.73, -0.25, 0.21, -0.17, -0.04, 0.08, 0.64, -0.25], [ 0.29, -0.35, -0.34, 0.77, 0. , 0.03, 0.13, 0.82, 0.78, 0.64, 0.67, -0.04, 0.36, 0.79, 0.89], [ 0.79, 0.56, -0.79, 0.57, 0. , -0.44, -0.62, 0.69, -0.21, -0.34, -0.22, 0.8 , -0.08, -0.54, 0.87], [-0.76, -0.18, -0.37, -0.72, 0. , 0.46, 0.64, 0.7 , -0.16, 0.76, 0.31, 0.84, 0. , 0.39, -0.1 ], [ 0.69, 0.66, 0.62, -0.07, 0. , 0.45, 0.47, 0.44, 0.69, -0.03, 0.89, 0.19, -0.57, -0.73, 0.52], [-0.37, -0.05, -0.29, -0.29, 0. , 0.83, 0.42, -0.75, 0. , 0.05, -0.35, 0.36, -0.13, -0.07, 0.04], [-0.78, -0.71, 0.66, 0.22, 0. , -0.67, 0.8 , 0.2 , 0.15, 0.39, -0.6 , 0.62, 0.22, -0.75, 0.12], [-0.65, -0.73, 0.45, -0.56, 0. , 0.07, 0.79, 0.75, 0.27, 0.83, -0.78, 0.85, -0.57, 0.35, -0.69], [-0.28, -0.09, -0.32, -0.34, 0. , -0.55, -0.63, 0.18, 0.46, -0.49, -0.43, 0.54, -0.09, 0.84, -0.08], [ 0.12, 0.4 , 0.77, 0.4 , 0. , 0.04, 0.66, 0.3 , -0.6 , -0.48, -0.48, 0.6 , 0.11, -0.36, 0.14]])

# %%
#Выведем матрицу А
A
#A.shape
# Out:
# array([[-0.05, -0.07,  0.34, -0.42,  0.  , -0.04, -0.33,  0.22,  0.28,
#          0.43, -0.2 ,  0.26,  0.1 , -0.8 , -0.62],
#        [ 0.62,  0.76,  0.68, -0.36,  0.  ,  0.39,  0.41,  0.81,  0.84,
#          0.48,  0.36,  0.11, -0.02, -0.79,  0.37],
#        [-0.36, -0.59,  0.68, -0.11,  0.  , -0.4 , -0.78, -0.59, -0.31,
#          0.11, -0.38,  0.18,  0.24,  0.23,  0.75],
#        [ 0.28,  0.17,  0.87, -0.53,  0.  , -0.39,  0.34, -0.17,  0.15,
#         -0.21,  0.34, -0.29, -0.41,  0.68,  0.62],
#        [-0.08,  0.07,  0.09, -0.3 ,  0.  , -0.73,  0.14,  0.38,  0.1 ,
#         -0.02, -0.55, -0.1 ,  0.31,  0.88,  0.18],
#        [-0.4 ,  0.41,  0.1 , -0.33,  0.  , -0.28,  0.1 ,  0.73, -0.25,
#          0.21, -0.17, -0.04,  0.08,  0.64, -0.25],
#        [ 0.29, -0.35, -0.34,  0.77,  0.  ,  0.03,  0.13,  0.82,  0.78,
#          0.64,  0.67, -0.04,  0.36,  0.79,  0.89],
#        [ 0.79,  0.56, -0.79,  0.57,  0.  , -0.44, -0.62,  0.69, -0.21,
# ...

# %%
B = np.array([ [-70, -28,  19,  34, -70,  37,  84, -49,  -4, -74,  51,   6,  46,
     75,  42],
   [ 66,  15, -79,  66, -13,   0,  17, -15,   8,  25,  77,  64,  23,
     34,  30],
   [ -1,  34,  67, -13,  -7, -74, -63, -25,  48,  82,  38,  35,  30,
     32, -16],
   [ 74,  20, -53,   1, -28, -23,  73,  15, -27,  42, -62, -74,  51,
     87,  46],
   [ 55,  46,  33,  83,  80,  31,  21, -71,  26, -46,  39, -16,  77,
     29, -35],
   [ 78, -45, -16, -55, -79,  61, -77, -76,  55,  72,  29, -11, -58,
     28,  52],
   [  9, -78, -46,  87, -30, -16,  -5,  44, -30, -16, -26, -48,  -7,
     34, -40],
   [ 61, -47,  18, -16, -61, -55,  25,  37,  55,  66,  -5, -68, -29,
    -22,  40],
   [ -7, -44,  -6,  22,  36,  79, -15, -13,  24,   2,  57,  13, -47,
     27, -22],
   [ 58, -56, -65,  44, -53, -79,  21,  -7, -77,  31,  70,  55,  72,
    -50,  -6],
   [ 64, -29,  16, -61,  63, -52, -34, -19,  13, -74,  68, -66,  58,
      7,  55],
   [-79,  21, -64, -59, -16, -30,   4,   5, -54,   4,  20,  52, -11,
    -20,  -2],
   [-44, -72,  41, -33, -35,  34, -17,  47,   1,  25, -70,  26, -35,
     57, -47],
   [ 53,  38, -55, -24, -42,  33,  74,  32,  83,  79, -25,   2, -27,
    -19,  46],
   [ 11,  29,  10,  18,  39,  -1, -45, -56,  -6,  -7, -46,  10,  23,
      5,   4]])

# %%
# Выведем матрицу B
B
#B.shape
# Out:
# array([[-70, -28,  19,  34, -70,  37,  84, -49,  -4, -74,  51,   6,  46,
#          75,  42],
#        [ 66,  15, -79,  66, -13,   0,  17, -15,   8,  25,  77,  64,  23,
#          34,  30],
#        [ -1,  34,  67, -13,  -7, -74, -63, -25,  48,  82,  38,  35,  30,
#          32, -16],
#        [ 74,  20, -53,   1, -28, -23,  73,  15, -27,  42, -62, -74,  51,
#          87,  46],
#        [ 55,  46,  33,  83,  80,  31,  21, -71,  26, -46,  39, -16,  77,
#          29, -35],
#        [ 78, -45, -16, -55, -79,  61, -77, -76,  55,  72,  29, -11, -58,
#          28,  52],
#        [  9, -78, -46,  87, -30, -16,  -5,  44, -30, -16, -26, -48,  -7,
#          34, -40],
#        [ 61, -47,  18, -16, -61, -55,  25,  37,  55,  66,  -5, -68, -29,
#         -22,  40],
#        [ -7, -44,  -6,  22,  36,  79, -15, -13,  24,   2,  57,  13, -47,
#          27, -22],
#        [ 58, -56, -65,  44, -53, -79,  21,  -7, -77,  31,  70,  55,  72,
#         -50,  -6],
# ...

# %%
b = np.array([ 8.5, 7.8, 2.4, -4.4, -0.6, 7.7, -3.2, -5.3, -4. , -5.6, -3.7, -2.2, 8.1, -1.1, 2.3])

# %%
# выведем наш вектор b
b
#b.shape
# Out:
# array([ 8.5,  7.8,  2.4, -4.4, -0.6,  7.7, -3.2, -5.3, -4. , -5.6, -3.7,
#        -2.2,  8.1, -1.1,  2.3])

# %%
# Найдете матрицу последовательного применения операторов А и В
# 1.применяем: x' = A*x, т.е. для нас это v1 = A@b

v1 = A@b
v1
# Out:
# array([ -1.821,   5.748,   2.047,   2.249,  -2.757,  -4.945, -14.001,
#          5.363, -15.07 ,   3.517,   5.406, -19.376, -24.94 ,  -6.057,
#          7.987])

# %%
# Шаг 2:
# x'' = B*x', т.е. для нас это будет : v2 = B @ v1

v2 = B @ v1
v2
# Out:
# array([-2653.55 , -1726.251,  -539.132,  -654.974, -3038.508,  1516.034,
#          939.057,  1777.987,   -18.045, -1214.986,   210.535,   472.063,
#         -562.658,  -947.503,  -513.84 ])

# %%
# Шаг 3 , сделаем проверку:
# нужно перемножить наши матрицы и вектор, т.е. :
#мы получаем ответ,такой же ,как  значение v2 выше.
#Также внимание, нужно начинать умножение с матрицы B

B @ A @ b
# Out:
# array([-2653.55 , -1726.251,  -539.132,  -654.974, -3038.508,  1516.034,
#          939.057,  1777.987,   -18.045, -1214.986,   210.535,   472.063,
#         -562.658,  -947.503,  -513.84 ])

# %% [markdown]
# Дана матрица data
#
#
#        [[2,4,3], [0,3,2], [-2,4,-1], [-5, 1,3], [-6,1,-4], [-2,-1, -2], \
#         [5,5,0], [5,2,3], [5,3,2], [4,1,-3], [3,-1,2], [2, -3,-1], [-2,-3,1]]
#
#
# 1. Найдите сингулярное разложение данной матрицы.
# 2. Какой размер имеет матрица правых сингулярных векторов?
# 3. Обрузуют ли базис правые сингулярные векторы? если да, то почему?

# %%
data = np.array([[2,4,3], [0,3,2], [-2,4,-1], [-5, 1,3], [-6,1,-4], [-2,-1, -2], \
    [5,5,0], [5,2,3], [5,3,2], [4,1,-3], [3,-1,2], [2, -3,-1], [-2,-3,1]])

# %%
# выведем нашу матрицу data
data
#data.shape
#:(13, 3)
# Out:
# array([[ 2,  4,  3],
#        [ 0,  3,  2],
#        [-2,  4, -1],
#        [-5,  1,  3],
#        [-6,  1, -4],
#        [-2, -1, -2],
#        [ 5,  5,  0],
#        [ 5,  2,  3],
#        [ 5,  3,  2],
#        [ 4,  1, -3],
#        [ 3, -1,  2],
#        [ 2, -3, -1],
#        [-2, -3,  1]])

# %%
# Чтобы точки нарисовать мы транспонируем матрицу
data.T
# Out:
# array([[ 2,  0, -2, -5, -6, -2,  5,  5,  5,  4,  3,  2, -2],
#        [ 4,  3,  4,  1,  1, -1,  5,  2,  3,  1, -1, -3, -3],
#        [ 3,  2, -1,  3, -4, -2,  0,  3,  2, -3,  2, -1,  1]])

# %%
data.shape
# Out:
# (13, 3)

# %%
# разделим наш массив как на лекции для рисования
set1 = np.array([[2,4,3], [0,3,2], [-2,4,-1], [-5, 1,3], [-6,1,-4], [-2,-1, -2]])
set2 = np.array([[5,5,0], [5,2,3], [5,3,2], [4,1,-3], [3,-1,2], [2, -3,-1], [-2,-3,1]])

# %%
set1
# Out:
# array([[ 2,  4,  3],
#        [ 0,  3,  2],
#        [-2,  4, -1],
#        [-5,  1,  3],
#        [-6,  1, -4],
#        [-2, -1, -2]])

# %%
set2
# Out:
# array([[ 5,  5,  0],
#        [ 5,  2,  3],
#        [ 5,  3,  2],
#        [ 4,  1, -3],
#        [ 3, -1,  2],
#        [ 2, -3, -1],
#        [-2, -3,  1]])

# %%
set1.T
# Out:
# array([[ 2,  0, -2, -5, -6, -2],
#        [ 4,  3,  4,  1,  1, -1],
#        [ 3,  2, -1,  3, -4, -2]])

# %%
set2.T
# Out:
# array([[ 5,  5,  5,  4,  3,  2, -2],
#        [ 5,  2,  3,  1, -1, -3, -3],
#        [ 0,  3,  2, -3,  2, -1,  1]])

# %%
x1 = set1.T[0]
y1 = set1.T[1]
z1 = set1.T[2]

x2 = set2.T[0]
y2 = set2.T[1]
z2 = set2.T[2]

print(x1)
print(y1)
print(x2)
print(y2)
print(z1)
print(z2)
# Out:
# [ 2  0 -2 -5 -6 -2]
# [ 4  3  4  1  1 -1]
# [ 5  5  5  4  3  2 -2]
# [ 5  2  3  1 -1 -3 -3]
# [ 3  2 -1  3 -4 -2]
# [ 0  3  2 -3  2 -1  1]

# %%
#  Собственное разложение
#  где U матрица порядка mXm,состоит из левых векторов, Vt:транспонированная матрица порядка nXn, из правых векторов. 
#  S - матрица порядка mXn,где элементы на главной диагонали сингулярные числа.
U , S, Vt = np.linalg.svd(data)

# %%
# размер должен быть m X m,  в нашем случае 13 на 13, так как матрица data имеет размер 13 на 3
U.shape
# Out:
# (13, 13)

# %%
#vt размер должен быть n X n  в нашем случае 3 на 3, так как матрица data имеет размер 13 на 3
Vt.shape
# Out:
# (3, 3)

# %%
# S  Это наши сингулярные числа
S
# Out:
# array([14.54623026,  9.22140506,  7.57448837])

# %%
#2. Какой размер имеет матрица правых сингулярных векторов?

# в нашем случае 3 на 3, так как матрица data имеет размер 13 на 3
#(3, 3)

# %%
# 3. Обрузуют ли базис правые сингулярные векторы? если да, то почему?

# Векторы образуют базис, если определитель, составленный из координат этих векторов, отличен от нуля, 
# в противном случае вектора не являются базисными и вектор X нельзя разложить по данному базису.
#
#

detVt= np.linalg.det(Vt)
detVt
# Out:
# -1.0
