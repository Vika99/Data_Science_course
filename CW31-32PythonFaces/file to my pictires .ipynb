# %%
import os
import glob
import pandas as pd
import xml.etree.ElementTree as ET


# In[2]:


def xml_to_csv(path):
    xml_list = []
    
    for xml_file in glob.glob(path + '/*.xml'):
        
        print(xml_file)
        tree = ET.parse(xml_file)
        root = tree.getroot()
        for member in root.findall('object'):
            value = (root.find('filename').text,
                     int(root.find('size')[0].text),
                     int(root.find('size')[1].text),
                     member[0].text,
                     int(member[4][0].text),
                     int(member[4][1].text),
                     int(member[4][2].text),
                     int(member[4][3].text)
                     )
            xml_list.append(value)
    column_name = ['filename', 'width', 'height', 'clas', 'xmin', 'ymin', 'xmax', 'ymax']
    xml_df = pd.DataFrame(xml_list, columns=column_name)
    return xml_df


# In[3]:


#os.path.join(os.getcwd(), '/numsAnno')


# In[4]:


image_path = os.path.join(os.getcwd(), 'annotation')
xml_df = xml_to_csv(image_path)
xml_df = xml_df.sort_values(by=['filename'])
xml_df.to_csv('Annotated_faces_.csv', index=None)
print('Successfully converted xml to csv.', xml_df.shape[0])
# Out:
# C:\Users\laptop\Desktop\Data Science\CW 30\annotation\pic_0.xml
# C:\Users\laptop\Desktop\Data Science\CW 30\annotation\pic_1.xml
# C:\Users\laptop\Desktop\Data Science\CW 30\annotation\pic_10.xml
# C:\Users\laptop\Desktop\Data Science\CW 30\annotation\pic_1008.xml
# C:\Users\laptop\Desktop\Data Science\CW 30\annotation\pic_11.xml
# C:\Users\laptop\Desktop\Data Science\CW 30\annotation\pic_12.xml
# C:\Users\laptop\Desktop\Data Science\CW 30\annotation\pic_121.xml
# C:\Users\laptop\Desktop\Data Science\CW 30\annotation\pic_122.xml
# C:\Users\laptop\Desktop\Data Science\CW 30\annotation\pic_13.xml
# C:\Users\laptop\Desktop\Data Science\CW 30\annotation\pic_138.xml
# C:\Users\laptop\Desktop\Data Science\CW 30\annotation\pic_14.xml
# C:\Users\laptop\Desktop\Data Science\CW 30\annotation\pic_143.xml
# C:\Users\laptop\Desktop\Data Science\CW 30\annotation\pic_15.xml
# C:\Users\laptop\Desktop\Data Science\CW 30\annotation\pic_16.xml
# ...

# %% [raw]
# # заметка, чтобы не было проблем с файлом, надо идти в браузере у меня в Jupyter -> потом идем папка decstop -> потом нашу нужную
# # папку выбираем,в нашес случае Data Science -> Нажимаем на нашу след.папку (наш случай CW30) и там создаем питон файл( тот,который сейчас мы создали и все работает!)

# %%
df = pd.read_csv("Annotated_faces_.csv")

# %%
df
# Out:
#          filename  width  height  clas  xmin  ymin  xmax  ymax
# 0       pic_0.jpg    640     480  vika   266     9   508   236
# 1       pic_1.jpg    640     480  vika   296    17   470   235
# 2      pic_10.jpg    640     480  vika   289    11   486   244
# 3    pic_1008.jpg    640     480  vika   295    84   502   356
# 4      pic_11.jpg    640     480  vika   283    15   484   241
# ..            ...    ...     ...   ...   ...   ...   ...   ...
# 108     pic_9.jpg    640     480  vika   280     1   459   239
# 109     pic_9.jpg    640     480  vika   297    28   459   194
# 110   pic_915.jpg    640     480  vika   296    83   501   359
# 111    pic_96.jpg    640     480  vika   329     3   516   308
# 112    pic_97.jpg    640     480  vika   333    10   522   312
#
# [113 rows x 8 columns]
